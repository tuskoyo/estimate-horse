# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2

import time

# %%
img = cv2.imread('/home/osamu/horse_data/uma/uma.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img2 = cv2.imread('/home/osamu/horse_data/uma_out/uma.jpg')
plt.imshow(img2)

# %%
df = pd.read_csv('/home/osamu/horse_data/uma_out/position.csv', sep=',')

# %%
df.iloc[0]
# Out:
# frame                    1.000000
# left_eye_x             203.201126
# left_eye_y              78.605804
# right_eye_x            196.938660
# right_eye_y             75.474579
# left_ear_x             215.726044
# left_ear_y              66.080879
# right_ear_x            203.201126
# right_ear_y             59.818420
# nose_x                 165.626358
# nose_y                 109.918121
# throad_x               243.907135
# throad_y               144.361664
# tailbaes_x             431.781006
# tailbaes_y             178.805206
# withers_x              297.138062
# withers_y              131.836731
# left_front_elbow_x     303.400513
# left_front_elbow_y     225.773666
# right_front_elbow_x    278.350677
# right_front_elbow_y    241.429825
# left_back_elbow_x      422.387299
# left_back_elbow_y      213.248749
# right_back_elbow_x     394.206207
# right_back_elbow_y     235.167358
# left_front_knee_x      312.794220
# left_front_knee_y      291.529510
# ...

# %%
img2 = cv2.imread('/home/osamu/horse_data/uma/uma.jpg')
plt.imshow(img)

# %%
#imgのkye_dict[keypoint[0]]に点を描画
#
count = 2
img = cv2.imread('/home/osamu/horse_data/uma/uma.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
x, y = key_dict[f"{count}_{keypoints[count]}"]
cv2.circle(img, (int(x), int(y)), 5, (0, 255, 0), -1)
plt.imshow(img)
print(keypoints[count])
# Out:
# nose

# %%
img = cv2.imread("/home/osamu/horse_data/0510/bigred-c100-2024-05-10/bigred-c100/2024-05-10/22_00_22.83.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
df = pd.read_csv("/home/osamu/horse_data/c100_nonpic/position.csv")
x1 = df.iloc[0]["x1"] + 20
y1 = df.iloc[0]["y1"] + 20
x2 = df.iloc[0]["x2"] - 20
y2 = df.iloc[0]["y2"] - 20

x3 = df.iloc[0]["x1"] + 20
y3 = df.iloc[0]["y2"] - 20
x4 = df.iloc[0]["x2"] - 20
y4 = df.iloc[0]["y1"] + 20

x1, y1, x2, y2
# Out:
# (597.526123046875, 20.0, 1900.0, 1046.86865234375)

# %%
cv2.circle(img, (int(x1), int(y1)), 5, (0, 255, 0), -1)
cv2.circle(img, (int(x2), int(y2)), 5, (0, 255, 0), -1)
cv2.circle(img, (int(x3), int(y3)), 5, (0, 255, 0), -1)
cv2.circle(img, (int(x4), int(y4)), 5, (0, 255, 0), -1)
cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)


plt.imshow(img)

# %%
#dfのカラムx1欠損値の確認
df["x1"].isnull().sum()
# Out:
# 1293
